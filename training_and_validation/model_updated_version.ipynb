# %%
import xgboost as xgb
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV
import shap

# %%
df = pd.read_csv(r"C:\Users\chech\OneDrive\Documentos\StudyNights\test-rappi-DS\assets\house_sales.csv")
df.head()
# Out:
#     price  num_bed  num_bath  size_house  size_lot  num_floors  is_waterfront  \
# 0  221900        3      1.00        1180      5650         1.0              0
# 1  538000        3      2.25        2570      7242         2.0              0
# 2  180000        2      1.00         770     10000         1.0              0
# 3  604000        4      3.00        1960      5000         1.0              0
# 4  510000        3      2.00        1680      8080         1.0              0
#
#    condition  size_basement  year_built  renovation_date    zip   latitude  \
# 0          3              0        1955                0  98178  47.511234
# 1          3            400        1951             1991  98125  47.721023
# 2          3              0        1933                0  98028  47.737927
# 3          5            910        1965                0  98136  47.520820
# 4          3              0        1987                0  98074  47.616812
#
#     longitude  avg_size_neighbor_houses  avg_size_neighbor_lot
# 0 -122.256775                      1340                   5650
# 1 -122.318862                      1690                   7639
# 2 -122.233196                      2720                   8062
# 3 -122.393185                      1360                   5000
# 4 -122.044901                      1800                   7503

# %% [markdown]
# The links we are using are:
# https://github.com/slundberg/shap
# https://shap-lrjball.readthedocs.io/en/latest/generated/shap.summary_plot.html
# https://blog.cambridgespark.com/hyperparameter-tuning-in-xgboost-4ff9100a3b2f
# https://wellsr.com/python/data-scaling-and-normalization-with-python/
# https://towardsdatascience.com/xgboost-fine-tune-and-optimize-your-model-23d996fab663

# %% [markdown]
# So, lets first go ahead and separate our data between features, and the target. In this case, the target is Price

# %%
target = df.price
df_features = df.drop(['price'], axis =1)

# %% [markdown]
# Given that we are going to train with xgboost, we may either use the Matrix version or the sckit-learn API (https://towardsdatascience.com/xgboost-fine-tune-and-optimize-your-model-23d996fab663 for reference), where we need to calculate our metrics. We will be using RMSE.

# %%
xtrain, xtest, ytrain, ytest = train_test_split(df_features, target, test_size=0.2)
xgbr = xgb.XGBRegressor(objective='reg:squarederror')
xgbr.fit(xtrain, ytrain)
 
ypred = xgbr.predict(xtest)
mse = mean_squared_error(ytest, ypred)
print("RMSE: %.2f" % (mse**(1/2.0)))
# Out:
# RMSE: 138989.26

# %% [markdown]
# So far so good, we haven't even told the xgb instace which values to the params we want to use. Let's maybe go ahead with a Hyperparameter Tuning, to see if maybe we can improve our RMSE metric.
# I am using the same example as of the page in, https://towardsdatascience.com/xgboost-fine-tune-and-optimize-your-model-23d996fab663, so the explanation of why we can choose the hyperparameter values is the same.
# For
# - max_depth: Default is 6, should be greater than zero. The higher value causes a deeper tree that can cause overfit, and we dont want that.
# - learning_rate: or eta, this is the step size. Default is 0.3.
# - n_estimators: Default is 100.
# - colsample_bytree: how many columns (fraction) each tree should take. Default is 1.

# %%
params = { 'max_depth': [3,6],
           'learning_rate': [0.01, 0.05],
           'n_estimators': [100, 500],
           'colsample_bytree': [0.3, 0.7]
           }
xgbr = xgb.XGBRegressor(seed = 20)
clf = GridSearchCV(estimator=xgbr, 
                   param_grid=params,
                   scoring='neg_mean_squared_error', 
                   verbose=1)

clf.fit(xtrain, ytrain)
print("Best parameters:", clf.best_params_)
print("Lowest RMSE: ", (-clf.best_score_)**(1/2.0))
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  80 out of  80 | elapsed:  1.8min finished
# Best parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 500}
# Lowest RMSE:  129305.89249836608

# %% [markdown]
# Given that i am running out of time, i will use the other way of xgboost (with matrices) so i can put the optimized parameters into training the model.

# %%
num_boost_round = 999

dtrain = xgb.DMatrix(xtrain, label=ytrain)
dtest = xgb.DMatrix(xtest, label=ytest)
model = xgb.train(
     clf.best_params_,
    dtrain,
    num_boost_round=num_boost_round,
    evals=[(dtest, "Test")],
    early_stopping_rounds=10
)
print("Best RMSE: {} with {} rounds".format(
                 model.best_score,
                 model.best_iteration+1))
# Out:
# [21:11:22] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	Test-rmse:631164.76656
# [1]	Test-rmse:603027.49870
# [2]	Test-rmse:576598.99212
# [3]	Test-rmse:551993.43465
# [4]	Test-rmse:528329.37157
# [5]	Test-rmse:505919.78472
# [6]	Test-rmse:485451.62470
# [7]	Test-rmse:464921.41644
# [8]	Test-rmse:445679.60571
# [9]	Test-rmse:428052.63554
# [10]	Test-rmse:411279.01143
# [11]	Test-rmse:394903.39120
# [12]	Test-rmse:378996.76673
# [13]	Test-rmse:364241.82178
# [14]	Test-rmse:350405.71507
# [15]	Test-rmse:337373.43466
# [16]	Test-rmse:325385.41244
# [17]	Test-rmse:313178.42519
# [18]	Test-rmse:302436.90648
# [19]	Test-rmse:292515.93649
# [20]	Test-rmse:283892.08940
# [21]	Test-rmse:275414.49360
# [22]	Test-rmse:266103.13980
# [23]	Test-rmse:258445.68258
# [24]	Test-rmse:250179.61751
# [25]	Test-rmse:243566.89871
# [26]	Test-rmse:237147.95888
# [27]	Test-rmse:230461.03011
# [28]	Test-rmse:224260.78546
# [29]	Test-rmse:218493.25123
# [30]	Test-rmse:213525.45860
# [31]	Test-rmse:208894.08293
# [32]	Test-rmse:204310.61905
# [33]	Test-rmse:199887.38021
# [34]	Test-rmse:195892.97466
# [35]	Test-rmse:191778.93554
# [36]	Test-rmse:188262.15904
# [37]	Test-rmse:185244.67597
# [38]	Test-rmse:182077.61279
# [39]	Test-rmse:179004.17067
# [40]	Test-rmse:176324.61427
# [41]	Test-rmse:174223.41864
# [42]	Test-rmse:172002.74686
# [43]	Test-rmse:170060.72985
# [44]	Test-rmse:167985.85026
# [45]	Test-rmse:166184.17702
# [46]	Test-rmse:164554.30861
# [47]	Test-rmse:163261.29389
# [48]	Test-rmse:161813.01499
# [49]	Test-rmse:160777.34817
# [50]	Test-rmse:159607.45744
# [51]	Test-rmse:158354.90295
# [52]	Test-rmse:156983.86491
# [53]	Test-rmse:156030.15475
# [54]	Test-rmse:155174.10388
# [55]	Test-rmse:154389.72745
# [56]	Test-rmse:153455.66154
# [57]	Test-rmse:152647.86167
# [58]	Test-rmse:151660.56324
# [59]	Test-rmse:151036.50199
# [60]	Test-rmse:150235.04140
# [61]	Test-rmse:149534.76531
# [62]	Test-rmse:149161.90957
# [63]	Test-rmse:148728.02412
# [64]	Test-rmse:148151.46819
# [65]	Test-rmse:147541.66351
# [66]	Test-rmse:147115.61126
# [67]	Test-rmse:146378.58169
# [68]	Test-rmse:146061.21470
# [69]	Test-rmse:145457.95615
# [70]	Test-rmse:145227.00826
# [71]	Test-rmse:144889.70534
# [72]	Test-rmse:144300.67557
# [73]	Test-rmse:144014.48741
# [74]	Test-rmse:143707.49110
# [75]	Test-rmse:143161.63535
# [76]	Test-rmse:142902.14076
# [77]	Test-rmse:142496.61106
# [78]	Test-rmse:142356.35152
# [79]	Test-rmse:142062.40453
# [80]	Test-rmse:141817.47258
# [81]	Test-rmse:141633.03717
# [82]	Test-rmse:141359.72781
# [83]	Test-rmse:141145.01087
# [84]	Test-rmse:140837.90786
# [85]	Test-rmse:140679.07274
# [86]	Test-rmse:140604.37538
# [87]	Test-rmse:140428.61704
# [88]	Test-rmse:140408.55795
# [89]	Test-rmse:140274.90479
# [90]	Test-rmse:140102.33236
# [91]	Test-rmse:139873.92286
# [92]	Test-rmse:139618.05220
# [93]	Test-rmse:139474.42065
# [94]	Test-rmse:139254.85966
# [95]	Test-rmse:139095.74493
# [96]	Test-rmse:138915.85890
# [97]	Test-rmse:138780.08764
# [98]	Test-rmse:138726.32427
# [99]	Test-rmse:138498.03750
# [100]	Test-rmse:138396.03261
# [101]	Test-rmse:138377.10919
# [102]	Test-rmse:138260.75002
# [103]	Test-rmse:138238.61428
# [104]	Test-rmse:138137.42227
# [105]	Test-rmse:138050.32714
# [106]	Test-rmse:138080.32246
# [107]	Test-rmse:137952.83015
# [108]	Test-rmse:137914.89058
# [109]	Test-rmse:137811.89354
# [110]	Test-rmse:137728.27277
# [111]	Test-rmse:137631.02645
# [112]	Test-rmse:137560.52746
# [113]	Test-rmse:137468.45071
# [114]	Test-rmse:137405.16509
# [115]	Test-rmse:137274.70945
# [116]	Test-rmse:137124.47176
# [117]	Test-rmse:137087.18533
# [118]	Test-rmse:136970.11824
# [119]	Test-rmse:136853.79924
# [120]	Test-rmse:136759.41952
# [121]	Test-rmse:136705.09566
# [122]	Test-rmse:136674.98981
# [123]	Test-rmse:136673.94249
# [124]	Test-rmse:136644.35476
# [125]	Test-rmse:136585.10035
# [126]	Test-rmse:136558.47524
# [127]	Test-rmse:136539.17182
# [128]	Test-rmse:136527.65461
# [129]	Test-rmse:136478.79093
# [130]	Test-rmse:136394.32642
# [131]	Test-rmse:136362.99789
# [132]	Test-rmse:136304.66959
# [133]	Test-rmse:136250.91352
# [134]	Test-rmse:136196.84356
# [135]	Test-rmse:136157.15667
# [136]	Test-rmse:136100.40981
# [137]	Test-rmse:136106.09415
# [138]	Test-rmse:135995.76807
# [139]	Test-rmse:135979.95528
# [140]	Test-rmse:135947.18931
# [141]	Test-rmse:135902.83722
# [142]	Test-rmse:135836.85973
# [143]	Test-rmse:135761.35037
# [144]	Test-rmse:135745.48711
# [145]	Test-rmse:135715.73973
# [146]	Test-rmse:135695.26885
# [147]	Test-rmse:135630.78813
# [148]	Test-rmse:135504.56788
# [149]	Test-rmse:135434.72261
# [150]	Test-rmse:135389.62056
# [151]	Test-rmse:135433.02822
# [152]	Test-rmse:135384.97057
# [153]	Test-rmse:135403.67736
# [154]	Test-rmse:135375.19788
# [155]	Test-rmse:135338.91972
# [156]	Test-rmse:135276.20716
# [157]	Test-rmse:135175.40909
# [158]	Test-rmse:135106.13739
# [159]	Test-rmse:134998.38336
# [160]	Test-rmse:134982.96569
# [161]	Test-rmse:134943.27888
# [162]	Test-rmse:134919.07779
# [163]	Test-rmse:134889.44280
# [164]	Test-rmse:134821.15913
# [165]	Test-rmse:134674.28976
# [166]	Test-rmse:134626.69351
# [167]	Test-rmse:134610.93870
# [168]	Test-rmse:134602.22869
# [169]	Test-rmse:134567.57514
# [170]	Test-rmse:134520.02421
# [171]	Test-rmse:134497.59013
# [172]	Test-rmse:134487.65750
# [173]	Test-rmse:134436.13623
# [174]	Test-rmse:134392.34662
# [175]	Test-rmse:134293.32079
# [176]	Test-rmse:134239.34465
# [177]	Test-rmse:134218.87650
# [178]	Test-rmse:134185.99668
# [179]	Test-rmse:134182.34221
# [180]	Test-rmse:134180.87851
# [181]	Test-rmse:134176.07921
# [182]	Test-rmse:134207.10732
# [183]	Test-rmse:134219.12064
# [184]	Test-rmse:134160.84888
# [185]	Test-rmse:134139.76310
# [186]	Test-rmse:134100.12199
# [187]	Test-rmse:134074.90222
# [188]	Test-rmse:134046.84038
# [189]	Test-rmse:134012.91891
# [190]	Test-rmse:133973.20033
# [191]	Test-rmse:133954.00465
# [192]	Test-rmse:133950.37913
# [193]	Test-rmse:133905.11266
# [194]	Test-rmse:133943.77855
# [195]	Test-rmse:133901.65312
# [196]	Test-rmse:133871.19416
# [197]	Test-rmse:133874.35074
# [198]	Test-rmse:133813.17940
# [199]	Test-rmse:133780.46011
# [200]	Test-rmse:133791.69290
# [201]	Test-rmse:133748.15102
# [202]	Test-rmse:133745.60394
# [203]	Test-rmse:133718.06801
# [204]	Test-rmse:133719.04462
# [205]	Test-rmse:133717.77010
# [206]	Test-rmse:133708.53208
# [207]	Test-rmse:133691.95962
# [208]	Test-rmse:133666.41366
# [209]	Test-rmse:133656.18081
# [210]	Test-rmse:133646.74286
# [211]	Test-rmse:133648.42139
# [212]	Test-rmse:133655.88774
# [213]	Test-rmse:133632.67933
# [214]	Test-rmse:133642.92853
# [215]	Test-rmse:133618.74621
# [216]	Test-rmse:133638.88176
# [217]	Test-rmse:133616.60158
# [218]	Test-rmse:133598.53219
# [219]	Test-rmse:133586.64248
# [220]	Test-rmse:133586.68877
# [221]	Test-rmse:133586.09439
# [222]	Test-rmse:133564.60680
# [223]	Test-rmse:133545.85421
# [224]	Test-rmse:133531.37776
# [225]	Test-rmse:133512.52275
# [226]	Test-rmse:133505.69883
# [227]	Test-rmse:133502.11449
# [228]	Test-rmse:133527.33355
# [229]	Test-rmse:133510.16536
# [230]	Test-rmse:133512.29176
# [231]	Test-rmse:133459.16403
# [232]	Test-rmse:133442.75448
# [233]	Test-rmse:133440.85425
# [234]	Test-rmse:133391.64873
# [235]	Test-rmse:133373.49792
# [236]	Test-rmse:133355.46261
# [237]	Test-rmse:133304.78153
# [238]	Test-rmse:133278.49390
# [239]	Test-rmse:133284.74026
# [240]	Test-rmse:133279.79252
# [241]	Test-rmse:133243.90386
# [242]	Test-rmse:133242.48282
# [243]	Test-rmse:133225.32320
# [244]	Test-rmse:133220.02423
# [245]	Test-rmse:133202.87928
# [246]	Test-rmse:133220.38857
# [247]	Test-rmse:133200.33866
# [248]	Test-rmse:133179.90288
# [249]	Test-rmse:133169.20389
# [250]	Test-rmse:133164.08973
# [251]	Test-rmse:133165.50297
# [252]	Test-rmse:133158.84035
# [253]	Test-rmse:133141.32333
# [254]	Test-rmse:133140.75316
# [255]	Test-rmse:133109.56817
# [256]	Test-rmse:133079.11788
# [257]	Test-rmse:133085.49565
# [258]	Test-rmse:133076.37017
# [259]	Test-rmse:133034.51268
# [260]	Test-rmse:133018.68044
# [261]	Test-rmse:133007.02627
# [262]	Test-rmse:132984.93336
# [263]	Test-rmse:132987.33952
# [264]	Test-rmse:132958.31205
# [265]	Test-rmse:132914.62000
# [266]	Test-rmse:132878.14982
# [267]	Test-rmse:132870.68345
# [268]	Test-rmse:132875.27587
# [269]	Test-rmse:132870.98631
# [270]	Test-rmse:132852.75799
# [271]	Test-rmse:132846.17989
# [272]	Test-rmse:132826.72259
# [273]	Test-rmse:132832.89225
# [274]	Test-rmse:132792.15826
# [275]	Test-rmse:132773.31862
# [276]	Test-rmse:132741.74940
# [277]	Test-rmse:132730.52050
# [278]	Test-rmse:132730.80423
# [279]	Test-rmse:132726.40970
# [280]	Test-rmse:132726.45752
# [281]	Test-rmse:132742.13703
# [282]	Test-rmse:132730.62018
# [283]	Test-rmse:132735.42263
# [284]	Test-rmse:132705.42656
# [285]	Test-rmse:132702.97541
# [286]	Test-rmse:132688.62688
# [287]	Test-rmse:132699.78427
# [288]	Test-rmse:132665.23156
# [289]	Test-rmse:132638.15294
# [290]	Test-rmse:132638.27547
# [291]	Test-rmse:132603.86543
# [292]	Test-rmse:132602.74065
# [293]	Test-rmse:132589.73240
# [294]	Test-rmse:132588.25001
# [295]	Test-rmse:132587.15923
# [296]	Test-rmse:132563.58751
# [297]	Test-rmse:132494.80469
# [298]	Test-rmse:132464.00333
# [299]	Test-rmse:132492.47369
# [300]	Test-rmse:132494.71700
# [301]	Test-rmse:132461.37564
# [302]	Test-rmse:132452.76124
# [303]	Test-rmse:132417.73968
# [304]	Test-rmse:132396.11033
# [305]	Test-rmse:132406.97385
# [306]	Test-rmse:132409.82727
# [307]	Test-rmse:132435.58103
# [308]	Test-rmse:132445.47384
# [309]	Test-rmse:132445.89577
# [310]	Test-rmse:132455.04762
# [311]	Test-rmse:132406.76963
# [312]	Test-rmse:132405.05179
# [313]	Test-rmse:132407.99527
# [314]	Test-rmse:132442.96842
# Best RMSE: 132396.11032914353 with 305 rounds

# %% [markdown]
# Now that we have our model tuned, let's check out which are the variables that have the most importance into getting our model trained to estimate the price houses for the given region.

# %%
explainer = shap.Explainer(model)
shap_values = explainer(xtest)
shap.summary_plot(shap_values, xtest, plot_type="bar", feature_names = df_features.columns.to_list())

# %%
import pickle
filename = r'C:\Users\chech\OneDrive\Documentos\StudyNights\test-rappi-DS\assets\finalized_model.pkl'
pickle.dump(model, open(filename, 'wb'))
